# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # BeautifulSoup

# %% [markdown]
# ## 基本使用

# %%
html = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title" name="dromouse"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1"><!-- Elsie --></a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>
<p class="story">...</p>
"""
# 进行格式化输出    
from bs4 import  BeautifulSoup
soup = BeautifulSoup(html,'lxml')
print(soup.prettify())
# 将 title 的内容输出出来
print(soup.title.string)
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title" name="dromouse">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     <!-- Elsie -->
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>
# The Dormouse's story

# %% [markdown]
# # 标签选择器
# ## 选择元素

# %%
html = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title" name="dromouse"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1"><!-- Elsie --></a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>
<p class="story">...</p>
"""
from bs4 import  BeautifulSoup
soup = BeautifulSoup(html,'lxml')
print(soup.title)
print(type(soup.title))
print(soup.head)
print(soup.p)  # 如果有多个  只取第一个
print(soup.body)
# Out:
# <title>The Dormouse's story</title>
# <class 'bs4.element.Tag'>
# <head><title>The Dormouse's story</title></head>
# <p class="title" name="dromouse"><b>The Dormouse's story</b></p>
# <body>
# <p class="title" name="dromouse"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1"><!-- Elsie --></a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>

# %% [markdown]
# ## 获取名称

# %%
html = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title" name="dromouse"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1"><!-- Elsie --></a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>
<p class="story">...</p>
"""
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'lxml')
print(soup.title.name)
print(soup.p.name)
# Out:
# title
# p

# %% [markdown]
# # 获取选择内容的属性

# %%
html = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title" name="dromouse"><b>The Dormouse's sssstory</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1"><!-- Elsie --></a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>
<p class="story">...</p>
"""
from bs4 import BeautifulSoup
soup  = BeautifulSoup(html,'lxml')
print(soup.p.attrs['name'])
print(soup.p['name'])
print(soup.p['class'])
print(soup.p.string)
# Out:
# dromouse
# dromouse
# ['title']
# The Dormouse's sssstory

# %% [markdown]
# # 获取内容

# %%
html = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title" name="dromouse"><b>The Dormouse's sssstory</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1"><!-- Elsie --></a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>
<p class="story">...</p>
"""
from bs4 import  BeautifulSoup
soup  = BeautifulSoup(html,'lxml')
print(soup.a.string)
# Out:
#  Elsie

# %% [markdown]
# # 嵌套选择

# %%
html = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title" name="dromouse"><b>The Dormouse's sssstory</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1"><!-- Elsie --></a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>
<p class="story">...</p>
"""
from bs4 import  BeautifulSoup
soup = BeautifulSoup(html,'lxml')
# 层层调用
print(soup.body.p.string)
# Out:
# The Dormouse's sssstory

# %% [markdown]
# # 获取标签的子节点

# %% [markdown]
# ## contents

# %%
html = '''<html>
 <head>
  <title>
   The Dormouse's story
  </title>
 </head>
 <body>
  <p class="title" name="dromouse">
   <b>
    The Dormouse's story
   </b>
  </p>
  <p class="story">
   Once upon a time there were three little sisters; and their names were
   <a class="sister" href="http://example.com/elsie" id="link1">
    <!-- Elsie -->
   </a>
   ,
   <a class="sister" href="http://example.com/lacie" id="link2">
    Lacie
   </a>
   and
   <a class="sister" href="http://example.com/tillie" id="link3">
    Tillie
   </a>
   ;
and they lived at the bottom of a well.
  </p>
  <p class="story">
   ...
  </p>
 </body>
</html>
'''
from bs4 import  BeautifulSoup
soup = BeautifulSoup(html,'lxml')
print(soup.body.contents)
print(len(soup.body.contents))
# Out:
# ['\n', <p class="title" name="dromouse">
# <b>
#     The Dormouse's story
#    </b>
# </p>, '\n', <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
# <!-- Elsie -->
# </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>, '\n', <p class="story">
#    ...
#   </p>, '\n']
# 7

# %% [markdown]
# ## children

# %%
html = '''<html>
 <head>
  <title>
   The Dormouse's story
  </title>
 </head>
 <body>
  <p class="title" name="dromouse">
   <b>
    The Dormouse's story
   </b>
  </p>
  <p class="story">
   Once upon a time there were three little sisters; and their names were
   <a class="sister" href="http://example.com/elsie" id="link1">
    <!-- Elsie -->
   </a>
   ,
   <a class="sister" href="http://example.com/lacie" id="link2">
    Lacie
   </a>
   and
   <a class="sister" href="http://example.com/tillie" id="link3">
    Tillie
   </a>
   ;
and they lived at the bottom of a well.
  </p>
  <p class="story">
   ...
  </p>
 </body>
</html>
'''
from bs4 import  BeautifulSoup
soup = BeautifulSoup(html,'lxml')
print(soup.body.children)
# 因为是一个迭代器  不能直接返回值     循环以下  将其输出
for i,child in enumerate(soup.body.children,0):
        print(i,child)
# Out:
# <list_iterator object at 0x000002D35C48D5C0>
# 0
#
# 1 <p class="title" name="dromouse">
# <b>
#     The Dormouse's story
#    </b>
# </p>
# 2
#
# 3 <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
# <!-- Elsie -->
# </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
# 4
#
# 5 <p class="story">
#    ...
#   </p>
# 6

# %% [markdown]
# ## 所有的子孙节点
# ### descendants

# %%
html = '''<html>
 <head>
  <title>
   The Dormouse's story
  </title>
 </head>
 <body>
  <p class="title" name="dromouse">
   <b>
    The Dormouse's story
   </b>
  </p>
  <p class="story">
   Once upon a time there were three little sisters; and their names were
   <a class="sister" href="http://example.com/elsie" id="link1">
    <!-- Elsie -->
   </a>
   ,
   <a class="sister" href="http://example.com/lacie" id="link2">
    Lacie
   </a>
   and
   <a class="sister" href="http://example.com/tillie" id="link3">
    Tillie
   </a>
   ;
and they lived at the bottom of a well.
  </p>
  <p class="story">
   ...
  </p>
 </body>
</html>
'''
from bs4 import  BeautifulSoup
soup = BeautifulSoup(html,'lxml')
print(soup.body.descendants)
for i,descendant in enumerate(soup.body.descendants,0):
    print(i,descendant)
# Out:
# <generator object descendants at 0x000002D35C480B48>
# 0
#
# 1 <p class="title" name="dromouse">
# <b>
#     The Dormouse's story
#    </b>
# </p>
# 2
#
# 3 <b>
#     The Dormouse's story
#    </b>
# 4
#     The Dormouse's story
#
# 5
#
# 6
#
# 7 <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
# <!-- Elsie -->
# </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
# 8
#    Once upon a time there were three little sisters; and their names were
#
# 9 <a class="sister" href="http://example.com/elsie" id="link1">
# <!-- Elsie -->
# </a>
# 10
#
# 11  Elsie
# 12
#
# 13
#    ,
#
# 14 <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
# 15
#     Lacie
#
# 16
#    and
#
# 17 <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
# 18
#     Tillie
#
# 19
#    ;
# and they lived at the bottom of a well.
#
# 20
#
# 21 <p class="story">
#    ...
#   </p>
# 22
#    ...
#
# 23

# %% [markdown]
# # 父节点和祖先节点

# %%
html = '''<html>
 <head>
  <title>
   The Dormouse's story
  </title>
 </head>
 <body>
  <p class="title" name="dromouse">
   <b>
    The Dormouse's story
   </b>
  </p>
  <p class="story">
   Once upon a time there were three little sisters; and their names were
   <a class="sister" href="http://example.com/elsie" id="link1">
    <!-- Elsie -->
   </a>
   ,
   <a class="sister" href="http://example.com/lacie" id="link2">
    Lacie
   </a>
   and
   <a class="sister" href="http://example.com/tillie" id="link3">
    Tillie
   </a>
   ;
and they lived at the bottom of a well.
  </p>
  <p class="story">
   ...
  </p>
 </body>
</html>
'''
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'lxml')
# 获取父节点
print(soup.a.parent)
# Out:
# <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
# <!-- Elsie -->
# </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>

# %%
html = '''<html>
 <head>
  <title>
   The Dormouse's story
  </title>
 </head>
 <body>
  <p class="title" name="dromouse">
   <b>
    The Dormouse's story
   </b>
  </p>
  <p class="story">
   Once upon a time there were three little sisters; and their names were
   <a class="sister" href="http://example.com/elsie" id="link1">
    <!-- Elsie -->
   </a>
   ,
   <a class="sister" href="http://example.com/lacie" id="link2">
    Lacie
   </a>
   and
   <a class="sister" href="http://example.com/tillie" id="link3">
    Tillie
   </a>
   ;
and they lived at the bottom of a well.
  </p>
  <p class="story">
   ...
  </p>
 </body>
</html>
'''
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'lxml')
# 获取祖先节点
print(soup.a.parents)
for i,parent in enumerate(soup.a.parents):
    print(i,parent)
# Out:
# <generator object parents at 0x000002D35C46AA98>
# 0 <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
# <!-- Elsie -->
# </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
# 1 <body>
# <p class="title" name="dromouse">
# <b>
#     The Dormouse's story
#    </b>
# </p>
# <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
# <!-- Elsie -->
# </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
# <p class="story">
#    ...
#   </p>
# </body>
# 2 <html>
# <head>
# <title>
#    The Dormouse's story
#   </title>
# </head>
# <body>
# <p class="title" name="dromouse">
# <b>
#     The Dormouse's story
#    </b>
# </p>
# <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
# <!-- Elsie -->
# </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
# <p class="story">
#    ...
#   </p>
# </body>
# </html>
# 3 <html>
# <head>
# <title>
#    The Dormouse's story
#   </title>
# </head>
# <body>
# <p class="title" name="dromouse">
# <b>
#     The Dormouse's story
#    </b>
# </p>
# <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
# <!-- Elsie -->
# </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
# <p class="story">
#    ...
#   </p>
# </body>
# </html>

# %% [markdown]
# # 兄弟节点
# ## next_siblings  previous_siblings

# %%
html = '''<html>
 <head>
  <title>
   The Dormouse's story
  </title>
 </head>
 <body>
  <p class="title" name="dromouse">
   <b>
    The Dormouse's story
   </b>
  </p>
  <p class="story">
   Once upon a time there were three little sisters; and their names were
   <a class="sister" href="http://example.com/elsie" id="link1">
    <!-- Elsie -->
   </a>
   ,
   <a class="sister" href="http://example.com/lacie" id="link2">
    Lacie
   </a>
   and
   <a class="sister" href="http://example.com/tillie" id="link3">
    Tillie
   </a>
   ;
and they lived at the bottom of a well.
  </p>
  <p class="story">
   ...
  </p>
 </body>
</html>
'''
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'lxml')
print(list(enumerate(soup.a.next_siblings)))   # 后面的兄弟节点
print(list(enumerate(soup.a.previous_siblings)))  # 前面的兄弟节点
# Out:
# [(0, '\n   ,\n   '), (1, <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>), (2, '\n   and\n   '), (3, <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>), (4, '\n   ;\nand they lived at the bottom of a well.\n  ')]
# [(0, '\n   Once upon a time there were three little sisters; and their names were\n   ')]

# %% [markdown]
# # 前后节点
# ## next_element  previous_element

# %%
html = '''<html>
 <head>
  <title>
   The Dormouse's story
  </title>
 </head>
 <body>
  <p class="title" name="dromouse">
   <b>
    The Dormouse's story
   </b>
  </p>
  <p class="story">
   Once upon a time there were three little sisters; and their names were
   <a class="sister" href="http://example.com/elsie" id="link1">
    <!-- Elsie -->
   </a>
   ,
   <a class="sister" href="http://example.com/lacie" id="link2">
    Lacie
   </a>
   and
   <a class="sister" href="http://example.com/tillie" id="link3">
    Tillie
   </a>
   ;
and they lived at the bottom of a well.
  </p>
  <p class="story">
   ...
  </p>
 </body>
</html>
'''
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'lxml')
print(soup.a.next_element)
print(list(enumerate(soup.stripped_strings)))
print(soup.a.previous_element)
# Out:
# [(0, "The Dormouse's story"), (1, "The Dormouse's story"), (2, 'Once upon a time there were three little sisters; and their names were'), (3, ','), (4, 'Lacie'), (5, 'and'), (6, 'Tillie'), (7, ';\nand they lived at the bottom of a well.'), (8, '...')]
#
#    Once upon a time there were three little sisters; and their names were

# %% [markdown]
# # 标准选择器
# ## find_all(name,attrs,recursive,text,**kwargs)
# ### 可根据标签名，属性，内容查找文档

# %% [markdown]
# ## name

# %%
html = '''<html>
 <head>
  <title>
   The Dormouse's story
  </title>
 </head>
 <body>
  <p class="title" name="dromouse">
   <b>
    The Dormouse's story
   </b>
  </p>
  <p class="story">
   Once upon a time there were three little sisters; and their names were
   <a class="sister" href="http://example.com/elsie" id="link1">
    <!-- Elsie -->
   </a>
   ,
   <a class="sister" href="http://example.com/lacie" id="link2">
    Lacie
   </a>
   and
   <a class="sister" href="http://example.com/tillie" id="link3">
    Tillie
   </a>
   ;
and they lived at the bottom of a well.
  </p>
  <p class="story">
   ...
  </p>
 </body>
</html>
'''
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'lxml')
# 可以传标签名
print(list(enumerate(soup.find_all('p'))))
print(soup.findAll('p')[0])
#结果是一个  tag类型的数据，意味着我们可以迭代的实现
print(type(soup.findAll('p')[0]))
# Out:
# [(0, <p class="title" name="dromouse">
# <b>
#     The Dormouse's story
#    </b>
# </p>), (1, <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
# <!-- Elsie -->
# </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>), (2, <p class="story">
#    ...
#   </p>)]
# <p class="title" name="dromouse">
# <b>
#     The Dormouse's story
#    </b>
# </p>
# <class 'bs4.element.Tag'>

# %%
html = '''<html>
 <head>
  <title>
   The Dormouse's story
  </title>
 </head>
 <body>
  <p class="title" name="dromouse">
   <b>
    The Dormouse's story
   </b>
  </p>
  <p class="story">
   Once upon a time there were three little sisters; and their names were
   <a class="sister" href="http://example.com/elsie" id="link1">
    <!-- Elsie -->
   </a>
   ,
   <a class="sister" href="http://example.com/lacie" id="link2">
    Lacie
   </a>
   and
   <a class="sister" href="http://example.com/tillie" id="link3">
    Tillie
   </a>
   ;
and they lived at the bottom of a well.
  </p>
  <p class="story">
    <a class="sister" href="http://example.com/tillie" id="link3">
    Tillie
   </a>
  </p>
 </body>
</html>
'''
soup = BeautifulSoup(html,'lxml')
for i in soup.find_all('p'):
    print(i.find_all('a'))
# Out:
# []
# [<a class="sister" href="http://example.com/elsie" id="link1">
# <!-- Elsie -->
# </a>, <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>, <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>]
# [<a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>]

# %% [markdown]
# ### attrs 参数
#   传入标签的属性

# %%
html = '''<html>
 <head>
  <title>
   The Dormouse's story
  </title>
 </head>
 <body>
  <p class="title" name="dromouse">
   <b>
    The Dormouse's story
   </b>
  </p>
  <p class="story">
   Once upon a time there were three little sisters; and their names were
   <a class="sister" href="http://example.com/elsie" id="link1">
    <!-- Elsie -->
   </a>
   ,
   <a class="sister" href="http://example.com/lacie" id="link2">
    Lacie
   </a>
   and
   <a class="sister" href="http://example.com/tillie" id="link3">
    Tillie
   </a>
   ;
and they lived at the bottom of a well.
  </p>
  <p class="story">
    <a class="sister" href="http://example.com/tillie" id="link3">
    Tillie
   </a>
  </p>
 </body>
</html>
'''
from bs4 import  BeautifulSoup
soup = BeautifulSoup(html,'lxml')
print(soup.find_all(attrs={'id':'link3'}))
print(soup.find_all(attrs={'href':'http://example.com/tillie'}))
print(soup.find_all(attrs={'class':'sister'}))
# Out:
# [<a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>, <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>]
# [<a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>, <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>]
# [<a class="sister" href="http://example.com/elsie" id="link1">
# <!-- Elsie -->
# </a>, <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>, <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>, <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>]

# %%
#  另一种  不用字典的形式传入
from bs4 import  BeautifulSoup
soup = BeautifulSoup(html,'lxml')
print(soup.find_all(id='link3'))
'''此处注意，如果需要传入class  因为class 是一个关键字，所以需要传入 class_   加一个下划线'''
print(soup.find_all(class_='sister'))
# Out:
# [<a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>, <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>]
# [<a class="sister" href="http://example.com/elsie" id="link1">
# <!-- Elsie -->
# </a>, <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>, <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>, <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>]

# %% [markdown]
# ### text  根据文本进行选择

# %%
html = '''
<html>
 <head>
  <title>
   The Dormouse's story
  </title>
 </head>
 <body>
  <p class="title" name="dromouse">
   <b>
    The Dormouse's story
   </b>
  </p>
  <p class="story">
   Once upon a time there were three little sisters; and their names were
   <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
   <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
   <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
   and they lived at the bottom of a well.
  </p>
  <p class="story">
    <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
  </p>
 </body>
</html>
'''
from bs4 import BeautifulSoup
soup =BeautifulSoup(html,'lxml')
print(soup.find_all(text='Tillie'))
soup.find_all(text=re.compile("Dormouse"))
# Out:
# ['Tillie', 'Tillie']
# ["\n   The Dormouse's story\n  ", "\n    The Dormouse's story\n   "]

# %% [markdown]
# # 传入正则表达式
# 如果传入正则表达式作为参数,Beautiful Soup会通过正则表达式的 match() 来匹配内容.下面例子中找出所有b的标签,这表示<body>和<b>标签都应该被找到

# %%
from bs4 import BeautifulSoup
import re
soup = BeautifulSoup(html,'lxml')
print(soup.findAll(class_=re.compile('s')))
# Out:
# [<p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
#    and they lived at the bottom of a well.
#   </p>, <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>, <p class="story">
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# </p>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# # 传列表
#
# 如果传入列表参数,Beautiful Soup会将与列表中任一元素匹配的内容返回.下面代码找到文档中所有<a>标签和<b>标签

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'lxml')
print(soup.find_all(['a','p']))
# Out:
# [<p class="title" name="dromouse">
# <b>
#     The Dormouse's story
#    </b>
# </p>, <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
#    and they lived at the bottom of a well.
#   </p>, <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>, <p class="story">
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# </p>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# # 传 True
#
# True 可以匹配任何值,下面代码查找到所有的tag,但是不会返回字符串节点

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'lxml')
print(list(enumerate(soup.find_all(True))))
for i in soup.findAll(True):
    print(i.name)
# Out:
# [(0, <html>
# <head>
# <title>
#    The Dormouse's story
#   </title>
# </head>
# <body>
# <p class="title" name="dromouse">
# <b>
#     The Dormouse's story
#    </b>
# </p>
# <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
#    and they lived at the bottom of a well.
#   </p>
# <p class="story">
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# </p>
# </body>
# </html>), (1, <head>
# <title>
#    The Dormouse's story
#   </title>
# </head>), (2, <title>
#    The Dormouse's story
#   </title>), (3, <body>
# <p class="title" name="dromouse">
# <b>
#     The Dormouse's story
#    </b>
# </p>
# <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
#    and they lived at the bottom of a well.
#   </p>
# <p class="story">
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# </p>
# </body>), (4, <p class="title" name="dromouse">
# <b>
#     The Dormouse's story
#    </b>
# </p>), (5, <b>
#     The Dormouse's story
#    </b>), (6, <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
#    and they lived at the bottom of a well.
#   </p>), (7, <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>), (8, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>), (9, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>), (10, <p class="story">
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# </p>), (11, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>)]
# html
# head
# title
# body
# p
# b
# p
# a
# a
# a
# p
# a

# %% [markdown]
# # 传方法
#
# 如果没有合适过滤器,那么还可以定义一个方法,方法只接受一个元素参数 [4] ,如果这个方法返回 True 表示当前元素匹配并且被找到,如果不是则反回 False
#
# 下面方法校验了当前元素,如果包含 class 属性却不包含 id 属性,那么将返回 True:

# %%
def has_class_but_no_id(tag):
    return tag.has_attr('class') and not tag.has_attr('id')

# %%
soup.find_all(has_class_but_no_id)
# Out:
# [<p class="title" name="dromouse">
#  <b>
#      The Dormouse's story
#     </b>
#  </p>, <p class="story">
#     Once upon a time there were three little sisters; and their names were
#     <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
#     and they lived at the bottom of a well.
#    </p>, <p class="story">
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
#  </p>]

# %%
soup.find_all("a", class_="sister")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find_all(href=re.compile("el"), id='link1')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>]

# %% [markdown]
# ## recursive 参数
#
# 调用tag的 find_all() 方法时,Beautiful Soup会检索当前tag的所有子孙节点,如果只想搜索tag的直接子节点,可以使用参数 recursive=False .

# %%
html1=''' <html>
 <head>
  <title>
   The Dormouse's story
  </title>
 </head>
...'''
print(soup.find_all(recursive=False,name='title'))
soup.find_all(recursive=True,name='title')
# Out:
# []
# [<title>
#     The Dormouse's story
#    </title>]

# %% [markdown]
# ## limit 参数
#
# find_all() 方法返回全部的搜索结构,如果文档树很大那么搜索会很慢.如果我们不需要全部结果,可以使用 limit 参数限制返回结果的数量.效果与SQL中的limit关键字类似,当搜索到的结果数量达到 limit 的限制时,就停止搜索返回结果.
#
# 文档树中有3个tag符合搜索条件,但结果只返回了2个,因为我们限制了返回数量

# %%
soup.find_all("a", class_="sister",limit=2)
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>]

# %% [markdown]
# ## find 方法
# ### find(name,attrs,recursive,text,**kwargs)
# find方法 和 find_all 方法的区别
# find方法返回的是匹配到的第一个值
# find_all返回的是所有匹配的结果   返回的是一个列表

# %%
html = '''
<html>
 <head>
  <title>
   The Dormouse's story
  </title>
 </head>
 <body>
  <p class="title" name="dromouse">
   <b>
    The Dormouse's story
   </b>
  </p>
  <p class="story">
   Once upon a time there were three little sisters; and their names were
   <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
   <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
   <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
   and they lived at the bottom of a well.
  </p>
  <p class="story">
    <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
  </p>
 </body>
</html>
'''
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'lxml')
# 返回第一个匹配的
print(soup.find('a'))
print(soup.find(class_='sister'))
print(soup.find(text='Elsie'))
print(soup.find(attrs={'id':'link1'}).string)
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# Elsie
# Elsie

# %% [markdown]
# ## find( name , attrs , recursive , text , **kwargs )
#
# 它与 find_all() 方法唯一的区别是 find_all() 方法的返回结果是值包含一个元素的列表,而 find() 方法直接返回结果
#
# ## find_parents()  find_parent()
#
# find_all() 和 find() 只搜索当前节点的所有子节点,孙子节点等. find_parents() 和 find_parent() 用来搜索当前节点的父辈节点,搜索方法与普通tag的搜索方法相同,搜索文档搜索文档包含的内容
#
# ## find_next_siblings()  find_next_sibling()
#
# 这2个方法通过 .next_siblings 属性对当 tag 的所有后面解析的兄弟 tag 节点进行迭代, find_next_siblings() 方法返回所有符合条件的后面的兄弟节点,find_next_sibling() 只返回符合条件的后面的第一个tag节点
#
# ## find_previous_siblings()  find_previous_sibling()
#
# 这2个方法通过 .previous_siblings 属性对当前 tag 的前面解析的兄弟 tag 节点进行迭代, find_previous_siblings() 方法返回所有符合条件的前面的兄弟节点, find_previous_sibling() 方法返回第一个符合条件的前面的兄弟节点
#
# ## find_all_next()  find_next()
#
# 这2个方法通过 .next_elements 属性对当前 tag 的之后的 tag 和字符串进行迭代, find_all_next() 方法返回所有符合条件的节点, find_next() 方法返回第一个符合条件的节点
#
# ## find_all_previous() 和 find_previous()
#
# 这2个方法通过 .previous_elements 属性对当前节点前面的 tag 和字符串进行迭代, find_all_previous() 方法返回所有符合条件的节点, find_previous()方法返回第一个符合条件的节点

# %% [markdown]
# # CSS 选择器
# 我们在写 CSS 时，标签名不加任何修饰，类名前加点，id名前加 #，
# 在这里我们也可以利用类似的方法来筛选元素，用到的方法是 soup.select()，返回类型是 list
#
# 可以通过  标签名 id 类名 组合  属性  等查找

# %%
html = '''
<html>
 <head>
  <title>
   The Dormouse's story
  </title>
 </head>
 <body>
  <p class="title" name="dromouse">
   <b>
    The Dormouse's story
   </b>
  </p>
  <p class="story">
   Once upon a time there were three little sisters; and their names were
   <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
   <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
   <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
   and they lived at the bottom of a well.
  </p>
  <p class="story">
    <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
  </p>
 </body>
</html>
'''
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'lxml')
print(soup.select('.story .sister'))
print(soup.select('#link1'))
print(soup.select('p b'))
print(soup.select('p')[0])
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>]
# [<b>
#     The Dormouse's story
#    </b>]
# <p class="title" name="dromouse">
# <b>
#     The Dormouse's story
#    </b>
# </p>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'lxml')
for p in soup.select('p'):
    print(p.select('a'))
# Out:
# []
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
# [<a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# ## 获取属性

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html,'lxml')
for a in soup.select('p a '):
    print(a['id'])
    print(a.attrs['id'])
# Out:
# link1
# link1
# link2
# link2
# link3
# link3
# link3
# link3

# %% [markdown]
# # 获取内容

# %%
for a in soup.select('a'):
    print(a.get_text())
# Out:
# Elsie
# Lacie
# Tillie
# Tillie

# %%
# 直接子标签查找
soup.select('p > b')
# Out:
# [<b>
#      The Dormouse's story
#     </b>]

# %%
soup.select('a[class="sister"]')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
