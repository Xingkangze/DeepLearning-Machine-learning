# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.empty((100,2))

# %%
X[:,0] = np.random.uniform(0.,100.,size=100)
X[:,1] = 0.75*X[:,0]+3. + np.random.normal(0.,10.,size=100)

# %%
#将样例的均值归为0
def demean(X):
    return X - np.mean(X,axis=0)
X = demean(X)

# %%
plt.scatter(X[:,0],X[:,1])
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 梯度
# ![image.png](attachment:image.png)

# %%
def f(w,X):
    return np.sum((X.dot(w)**2))  / len(X)

# %%
def df(w,X):
    return  X.T.dot(X.dot(w))*2.  / len(X)

# %%
#对于我们的w   实际上只代表方向，他的膜=1  ，当我们执行w = w + eta * gradient时，
#有可能我们的w不为1，因此我们需要对我们的w进行特殊处理，每一次都让w的膜等于1
#，让他成为一个单位方向向量    向量除以向量的膜
def direction(w):
    return w / np.linalg.norm(w)
def first_component(X,initial_w,eta,n_iter=1e4,epsilon=1e-8):
    w = direction(initial_w)
    cur_iter = 0
    while cur_iter<n_iter:
        gradient = df(w,X)
        last_w = w
        w = w + eta*gradient
        w = direction(w)
        if( abs(f(w,X) - f(last_w,X)) <epsilon ):
            break
        cur_iter +=1
    return w

# %%
initial_w = np.random.random(X.shape[1])
eta = 0.01
w = first_component(X,initial_w=initial_w,eta=eta)

# %%
w
# Out:
# array([ 0.7886027 ,  0.61490306])

# %% [markdown]
# ##  求第二主成分

# %%
X2 = np.empty(X.shape)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# for i in range(len(X)):
#     X2[i] = X[i]-X[i].dot(w)*w      
#向量化运算
X2 = X - X.dot(w).reshape(-1,1)*w

# %%
plt.scatter(X2[:,0],X2[:,1])
plt.show()

# %%
w2 = first_component(X2,initial_w,eta)

# %%
w2
# Out:
# array([ 0.5880655 , -0.80881331])

# %%
w
# Out:
# array([ 0.80881611,  0.58806164])

# %%
#验证是不是垂直的     结果趋近于0
w.dot(w2)
# Out:
# 4.7732277450029947e-06

# %%
#合并成一个函数
#给定一个n  给定一个X    求出他的前n个主成分分别是谁
def first_n_component(n,X,eta=0.01,n_iter = 1e4,epsilon = 1e-8):
    X_pca = X.copy()
    X_pca = demean(X_pca)
    res = []
    for i in range(n):
        initial_w = np.random.random(X_pca.shape[1])
        w = first_component(X_pca,initial_w,eta=eta)
        res.append(w)
        X_pca = X_pca - X_pca.dot(w).reshape(-1,1)*w
    return res

# %%
first_n_component(2,X)
# Out:
# [array([ 0.80881588,  0.58806197]), array([-0.58805924,  0.80881786])]
